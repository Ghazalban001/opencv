# %% [markdown]
# HSV
# تصویر سه کاناله

# %% [markdown]
# <p>Converting BGR color space to HSV</p>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("tabiat.jpg")

# %%
hsv_image=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
cv2.imshow("HSV imge",hsv_image)
cv2.imshow("Hue channel",hsv_image[:,:,0])
cv2.imshow("saturation channel",hsv_image[:,:,1])
cv2.imshow("value channel",hsv_image[:,:,2])

cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.figure(figsize=[20,5])
plt.subplot(131);plt.imshow(hsv_image[:,:,0],cmap="gray");plt.title("Hue channel");
plt.subplot(132);plt.imshow(hsv_image[:,:,1],cmap="gray");plt.title("vlaue channel");
plt.subplot(133);plt.imshow(hsv_image[:,:,2],cmap="gray");plt.title("saturation channel")
# Out:
# Text(0.5, 1.0, 'saturation channel')

# %%
saturated_image=cv2.merge([hsv_image[:,:,0],
                          cv2.add(hsv_image[:,:,1],50),
                          hsv_image[:,:,2]])
saturated_image=cv2.cvtColor(saturated_image,
                             cv2.COLOR_HSV2BGR)
plt.Figure(figsize=[12,5])

# %%
#show saturation image
plt.subplot(121);plt.imshow(saturated_image[...,::-1])
plt.title("saturation image")

#show main image
plt.subplot(122)
plt.imshow(img[...,::-1])
plt.title("orginl image")
# Out:
# Text(0.5, 1.0, 'orginl image')

# %%
#increses value in HSV

brighter_image=cv2.merge([hsv_image[:,:,0],
                          hsv_image[:,:,1],
                          cv2.add(hsv_image[:,:,2],50)])
plt.subplot(121);plt.imshow(brighter_image[...,::-1])
plt.title('saturated_image')

plt.subplot(122);plt.imshow(img[...,::-1])
plt.title("orginal image")
# Out:
# Text(0.5, 1.0, 'orginal image')
